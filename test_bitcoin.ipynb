# %%
import urllib.request
import ssl
import json
import time
import pandas as pd
import matplotlib.pyplot as plt
import requests
from config2 import db_password

# %%
from config import api_key

# %%
#select coins to querry
coin_list = [
"BTC",
"ETH",
"LTC",
"USDT",
"DOT",
"XRP",
"ADA",
"LINK",
"LTC",
"BCH",
"XLM"
]
coins = ','.join(coin_list)
coins
# Out:
# 'BTC,ETH,LTC,USDT,DOT,XRP,ADA,LINK,LTC,BCH,XLM'

# %%
#querry all data for a year of 1 coin
urls = []
for coin in coin_list:
    urls.append('https://api.lunarcrush.com/v2?data=assets&key='+ api_key + '&symbol='+coin+'&start=1262304000&end=1611878400&interval=day')
print(urls)
# Out:
# ['https://api.lunarcrush.com/v2?data=assets&key=rwch3wki8wwbjrof6pcn&symbol=BTC&start=1262304000&end=1611878400&interval=day', 'https://api.lunarcrush.com/v2?data=assets&key=rwch3wki8wwbjrof6pcn&symbol=ETH&start=1262304000&end=1611878400&interval=day', 'https://api.lunarcrush.com/v2?data=assets&key=rwch3wki8wwbjrof6pcn&symbol=LTC&start=1262304000&end=1611878400&interval=day', 'https://api.lunarcrush.com/v2?data=assets&key=rwch3wki8wwbjrof6pcn&symbol=USDT&start=1262304000&end=1611878400&interval=day', 'https://api.lunarcrush.com/v2?data=assets&key=rwch3wki8wwbjrof6pcn&symbol=DOT&start=1262304000&end=1611878400&interval=day', 'https://api.lunarcrush.com/v2?data=assets&key=rwch3wki8wwbjrof6pcn&symbol=XRP&start=1262304000&end=1611878400&interval=day', 'https://api.lunarcrush.com/v2?data=assets&key=rwch3wki8wwbjrof6pcn&symbol=ADA&start=1262304000&end=1611878400&interval=day', 'https://api.lunarcrush.com/v2?data=assets&key=rwch3wki8wwbjrof6pcn&symbol=LINK&start=1262304000&end=1611878400&in
# ...

# %%
bitcoin_json= []
for url in urls:
    bitcoin_json.append(requests.get(url).json())
bitcoin_json
# Out:
# [{'config': {'data': 'assets',
#    'end': 1611878400,
#    'interval': 'day',
#    'start': 1262304000,
#    'symbol': "'BTC'",
#    'data_points': 24},
#   'usage': {'day': 205, 'month': 450},
#   'data': [{'id': 1,
#     'name': 'Bitcoin',
#     'symbol': 'BTC',
#     'price': 33584.513803,
#     'price_btc': 1,
#     'market_cap': 625151577185,
#     'percent_change_24h': -0.27,
#     'percent_change_7d': -2.52,
#     'percent_change_30d': 16.17,
#     'volume_24h': 105968610216.59,
#     'max_supply': '21000000',
#     'timeSeries': [{'asset_id': 1,
#       'time': 1537315200,
#       'open': 6345.16,
#       'close': 6381.97,
#       'high': 6479.94,
#       'low': 6172.97,
#       'volume': 1944271041,
#       'market_cap': 110261455239.25,
#       'url_shares': None,
#       'unique_url_shares': None,
#       'reddit_posts': None,
#       'reddit_posts_score': None,
#       'reddit_comments': None,
#       'reddit_comments_score': None,
#       'tweets': None,
# ...

# %%
bitcoin_json[9]
# Out:
# {'config': {'data': 'assets',
#   'end': 1611878400,
#   'interval': 'day',
#   'start': 1262304000,
#   'symbol': "'BCH'",
#   'data_points': 24},
#  'usage': {'day': 214, 'month': 459},
#  'data': [{'id': 5,
#    'name': 'Bitcoin Cash',
#    'symbol': 'BCH',
#    'price': 397.800424,
#    'price_btc': 0.01184475758049318,
#    'market_cap': 7415211202,
#    'percent_change_24h': 0.25,
#    'percent_change_7d': -8.94,
#    'percent_change_30d': 14.82,
#    'volume_24h': 6359999289.87,
#    'max_supply': '21000000',
#    'timeSeries': [{'asset_id': 5,
#      'time': 1537315200,
#      'open': 434.6,
#      'close': 429.45,
#      'high': 443.56,
#      'low': 415.19,
#      'volume': 90568021,
#      'market_cap': 7454226902.85,
#      'url_shares': None,
#      'unique_url_shares': None,
#      'reddit_posts': None,
#      'reddit_posts_score': None,
#      'reddit_comments': None,
#      'reddit_comments_score': None,
#      'tweets': None,
#      'tweet_spam': None,
# ...

# %%
list = [] 
for i in range(10):
    
    for key in bitcoin_json[i].keys(): 
        list.append(key)
print(list)
# Out:
# ['config', 'usage', 'data', 'config', 'usage', 'data', 'config', 'usage', 'data', 'config', 'usage', 'data', 'config', 'usage', 'data', 'config', 'usage', 'data', 'config', 'usage', 'data', 'config', 'usage', 'data', 'config', 'usage', 'data', 'config', 'usage', 'data']

# %%
bitcoin_data = []
for i in range(10):
    bitcoin_data.append(bitcoin_json[i]['data'])
bitcoin_data
# Out:
# [[{'id': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'price': 33584.513803,
#    'price_btc': 1,
#    'market_cap': 625151577185,
#    'percent_change_24h': -0.27,
#    'percent_change_7d': -2.52,
#    'percent_change_30d': 16.17,
#    'volume_24h': 105968610216.59,
#    'max_supply': '21000000',
#    'timeSeries': [{'asset_id': 1,
#      'time': 1537315200,
#      'open': 6345.16,
#      'close': 6381.97,
#      'high': 6479.94,
#      'low': 6172.97,
#      'volume': 1944271041,
#      'market_cap': 110261455239.25,
#      'url_shares': None,
#      'unique_url_shares': None,
#      'reddit_posts': None,
#      'reddit_posts_score': None,
#      'reddit_comments': None,
#      'reddit_comments_score': None,
#      'tweets': None,
#      'tweet_spam': None,
#      'tweet_followers': None,
#      'tweet_quotes': None,
#      'tweet_retweets': None,
#      'tweet_replies': None,
#      'tweet_favorites': None,
#      'tweet_sentiment1': None,
# ...

# %%
bitcoin_id = []
for i in range(10):
    bitcoin_id.append(bitcoin_data[i][0])
bitcoin_id
# Out:
# [{'id': 1,
#   'name': 'Bitcoin',
#   'symbol': 'BTC',
#   'price': 33584.513803,
#   'price_btc': 1,
#   'market_cap': 625151577185,
#   'percent_change_24h': -0.27,
#   'percent_change_7d': -2.52,
#   'percent_change_30d': 16.17,
#   'volume_24h': 105968610216.59,
#   'max_supply': '21000000',
#   'timeSeries': [{'asset_id': 1,
#     'time': 1537315200,
#     'open': 6345.16,
#     'close': 6381.97,
#     'high': 6479.94,
#     'low': 6172.97,
#     'volume': 1944271041,
#     'market_cap': 110261455239.25,
#     'url_shares': None,
#     'unique_url_shares': None,
#     'reddit_posts': None,
#     'reddit_posts_score': None,
#     'reddit_comments': None,
#     'reddit_comments_score': None,
#     'tweets': None,
#     'tweet_spam': None,
#     'tweet_followers': None,
#     'tweet_quotes': None,
#     'tweet_retweets': None,
#     'tweet_replies': None,
#     'tweet_favorites': None,
#     'tweet_sentiment1': None,
#     'tweet_sentiment2': None,
#     'tweet_sentiment3': None,
# ...

# %%
keys = ['id','name','symbol','price','market_cap']
bitcoin_id_=[]
for key in keys:
    for i in range(10):
#         bitcoin_id_.append(bitcoin_id[i].iteritems(keys))
    
        bitcoin_id_.append({key: bitcoin_id[i][key] for key in bitcoin_id[i].keys() 
                               & {'id','name','symbol','price','market_cap'}})

# %%
bitcoin_id_
# Out:
# [{'price': 33584.513803,
#   'id': 1,
#   'name': 'Bitcoin',
#   'symbol': 'BTC',
#   'market_cap': 625151577185},
#  {'price': 1338.407809,
#   'id': 2,
#   'name': 'Ethereum',
#   'symbol': 'ETH',
#   'market_cap': 153192340858},
#  {'price': 131.785682,
#   'id': 4,
#   'name': 'Litecoin',
#   'symbol': 'LTC',
#   'market_cap': 8747831726},
#  {'price': 1.001686,
#   'id': 7,
#   'name': 'Tether',
#   'symbol': 'USDT',
#   'market_cap': 26391571090},
#  {'price': 16.760839,
#   'id': 2780,
#   'name': 'Polkadot',
#   'symbol': 'DOT',
#   'market_cap': 16063667946},
#  {'price': 0.277557,
#   'id': 3,
#   'name': 'XRP',
#   'symbol': 'XRP',
#   'market_cap': 12644423499},
#  {'price': 0.340909,
#   'id': 11,
#   'name': 'Cardano',
#   'symbol': 'ADA',
#   'market_cap': 10606539340},
#  {'price': 22.351788,
#   'id': 18,
#   'name': 'Chainlink',
#   'symbol': 'LINK',
#   'market_cap': 9030335763},
#  {'price': 131.785682,
#   'id': 4,
#   'name': 'Litecoin',
#   'symbol': 'LTC',
# ...

# %%
currencies_df = pd.DataFrame(bitcoin_id_)
currencies_df=currencies_df.drop_duplicates() 
currencies_df
# Out:
#           price    id          name symbol    market_cap
# 0  33584.513803     1       Bitcoin    BTC  625151577185
# 1   1338.407809     2      Ethereum    ETH  153192340858
# 2    131.785682     4      Litecoin    LTC    8747831726
# 3      1.001686     7        Tether   USDT   26391571090
# 4     16.760839  2780      Polkadot    DOT   16063667946
# 5      0.277557     3           XRP    XRP   12644423499
# 6      0.340909    11       Cardano    ADA   10606539340
# 7     22.351788    18     Chainlink   LINK    9030335763
# 9    397.800424     5  Bitcoin Cash    BCH    7415211202

# %%
output_data_file = "resources/Crpto_id.csv"
currencies_df.to_csv(output_data_file)

# %%
currencies_data = []
for i in range(10):
    currencies_data.append(bitcoin_data[i][0]['timeSeries'])
currencies_data
# Out:
# [[{'asset_id': 1,
#    'time': 1537315200,
#    'open': 6345.16,
#    'close': 6381.97,
#    'high': 6479.94,
#    'low': 6172.97,
#    'volume': 1944271041,
#    'market_cap': 110261455239.25,
#    'url_shares': None,
#    'unique_url_shares': None,
#    'reddit_posts': None,
#    'reddit_posts_score': None,
#    'reddit_comments': None,
#    'reddit_comments_score': None,
#    'tweets': None,
#    'tweet_spam': None,
#    'tweet_followers': None,
#    'tweet_quotes': None,
#    'tweet_retweets': None,
#    'tweet_replies': None,
#    'tweet_favorites': None,
#    'tweet_sentiment1': None,
#    'tweet_sentiment2': None,
#    'tweet_sentiment3': None,
#    'tweet_sentiment4': None,
#    'tweet_sentiment5': None,
#    'tweet_sentiment_impact1': None,
#    'tweet_sentiment_impact2': None,
#    'tweet_sentiment_impact3': None,
#    'tweet_sentiment_impact4': None,
#    'tweet_sentiment_impact5': None,
#    'social_score': None,
#    'average_sentiment': None,
# ...

# %%
len(currencies_data)
# Out:
# 10

# %%
currencies_data[6]
# Out:
# [{'asset_id': 11,
#   'time': 1537315200,
#   'open': 0.07,
#   'close': 0.07,
#   'high': 0.08,
#   'low': 0.07,
#   'volume': 83398513,
#   'market_cap': 1814894937.66,
#   'url_shares': None,
#   'unique_url_shares': None,
#   'reddit_posts': None,
#   'reddit_posts_score': None,
#   'reddit_comments': None,
#   'reddit_comments_score': None,
#   'tweets': None,
#   'tweet_spam': None,
#   'tweet_followers': None,
#   'tweet_quotes': None,
#   'tweet_retweets': None,
#   'tweet_replies': None,
#   'tweet_favorites': None,
#   'tweet_sentiment1': None,
#   'tweet_sentiment2': None,
#   'tweet_sentiment3': None,
#   'tweet_sentiment4': None,
#   'tweet_sentiment5': None,
#   'tweet_sentiment_impact1': None,
#   'tweet_sentiment_impact2': None,
#   'tweet_sentiment_impact3': None,
#   'tweet_sentiment_impact4': None,
#   'tweet_sentiment_impact5': None,
#   'social_score': None,
#   'average_sentiment': None,
#   'sentiment_absolute': None,
#   'sentiment_relative': None,
# ...

# %%
 
    
df1 = pd.DataFrame(currencies_data[0])
#     df2 = pd.DataFrame(currencies_data[1])
#     df3 = pd.DataFrame(currencies_data[2])
#     df4 = pd.DataFrame(currencies_data[3])
#     df5 = pd.DataFrame(currencies_data[4])
#     df6 = pd.DataFrame(currencies_data[5])
#     df7 = pd.DataFrame(currencies_data[6])
#     df8 = pd.DataFrame(currencies_data[7])
#     df9 = pd.DataFrame(currencies_data[8])
#     df0 = pd.DataFrame(currencies_data[9])

# %%
df1=df1.append(df2).append(df3).append(df4).append(df5).append(df6).append(df7).append(df8).append(df9).append(df0)

# %%
# bitcoin_data_dic['timeSeries']

# %%
# bitcoin_historic_data=bitcoin_data_dic['timeSeries'][3]
# type(bitcoin_historic_data)

# %%
# df = pd.DataFrame(bitcoin_data_dic['timeSeries'])
# df.head()

# %%
df1_columns=df1.columns
df1_columns
# Out:
# Index(['asset_id', 'time', 'open', 'close', 'high', 'low', 'volume',
#        'market_cap', 'url_shares', 'unique_url_shares', 'reddit_posts',
#        'reddit_posts_score', 'reddit_comments', 'reddit_comments_score',
#        'tweets', 'tweet_spam', 'tweet_followers', 'tweet_quotes',
#        'tweet_retweets', 'tweet_replies', 'tweet_favorites',
#        'tweet_sentiment1', 'tweet_sentiment2', 'tweet_sentiment3',
#        'tweet_sentiment4', 'tweet_sentiment5', 'tweet_sentiment_impact1',
#        'tweet_sentiment_impact2', 'tweet_sentiment_impact3',
#        'tweet_sentiment_impact4', 'tweet_sentiment_impact5', 'social_score',
#        'average_sentiment', 'sentiment_absolute', 'sentiment_relative',
#        'search_average', 'news', 'price_score', 'social_impact_score',
#        'correlation_rank', 'galaxy_score', 'volatility', 'alt_rank',
#        'alt_rank_30d', 'alt_rank_hour_average', 'market_cap_rank',
# ...

# %%
df1.dtypes
# Out:
# asset_id                     int64
# time                         int64
# open                       float64
# close                      float64
# high                       float64
# low                        float64
# volume                       int64
# market_cap                 float64
# url_shares                  object
# unique_url_shares           object
# reddit_posts               float64
# reddit_posts_score          object
# reddit_comments            float64
# reddit_comments_score      float64
# tweets                     float64
# tweet_spam                 float64
# tweet_followers             object
# tweet_quotes                object
# tweet_retweets              object
# tweet_replies               object
# tweet_favorites             object
# tweet_sentiment1           float64
# tweet_sentiment2           float64
# tweet_sentiment3           float64
# tweet_sentiment4           float64
# tweet_sentiment5           float64
# tweet_sentiment_impact1    float64
# ...

# %%
from datetime import datetime

# %%
from datetime import datetime
df1['time'] = pd.to_datetime(df1['time'], unit='s')

# %%
df1
# Out:
#       asset_id                time         open        close         high  \
# 0            1 2018-09-19 00:00:00  6345.160000  6381.970000  6479.940000
# 1            1 2018-09-20 00:00:00  6502.860000  6501.460000  6532.510000
# 2            1 2018-09-21 00:00:00  6657.170000  6780.810000  6780.810000
# 3            1 2018-09-22 00:00:00  6711.100000  6715.350000  6722.090000
# 4            1 2018-09-23 00:00:00  6758.310000  6713.100000  6758.310000
# ...        ...                 ...          ...          ...          ...
# 3646         5 2021-01-29 22:00:00   404.565491   407.947655   409.605685
# 3647         5 2021-01-29 23:00:00   405.568606   407.165541   410.286108
# 3648         5 2021-01-30 00:00:00   405.586184   402.055572   406.037575
# 3649         5 2021-01-30 01:00:00   402.448905   405.683899   407.206955
# 3650         5 2021-01-30 02:00:00   408.482411   406.542745   409.883165
#
#               low      volume    market_cap url_shares unique_url_shares  ...  \
# ...

# %%
df1=df1.reindex(columns= ['symbol','asset_id', 'time', 'open', 'close', 'high', 'low', 'volume',
       'market_cap', 'url_shares', 'unique_url_shares', 'reddit_posts',
       'reddit_posts_score', 'reddit_comments', 'reddit_comments_score',
       'tweets', 'tweet_spam', 'tweet_followers', 'tweet_quotes',
       'tweet_retweets', 'tweet_replies', 'tweet_favorites',
       'tweet_sentiment1', 'tweet_sentiment2', 'tweet_sentiment3',
       'tweet_sentiment4', 'tweet_sentiment5', 'tweet_sentiment_impact1',
       'tweet_sentiment_impact2', 'tweet_sentiment_impact3',
       'tweet_sentiment_impact4', 'tweet_sentiment_impact5', 'social_score',
       'average_sentiment', 'sentiment_absolute', 'sentiment_relative',
       'search_average', 'news', 'price_score', 'social_impact_score',
       'correlation_rank', 'galaxy_score', 'volatility', 'alt_rank',
       'alt_rank_30d', 'alt_rank_hour_average', 'market_cap_rank',
       'percent_change_24h_rank', 'volume_24h_rank', 'social_volume_24h_rank',
       'social_score_24h_rank', 'medium', 'youtube', 'social_contributors',
       'social_volume', 'price_btc', 'social_volume_global',
       'social_dominance', 'market_cap_global', 'market_dominance',
       'percent_change_24h'])

# %%
output_data_file = "resources/Crpto_data.csv"
# Export the City_Data into a CSV.
df1.to_csv(output_data_file)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-146-dc534d895528> in <module>
#       1 output_data_file = "resources/Crpto_data.csv"
#       2 # Export the City_Data into a CSV.
# ----> 3 df1.to_csv(output_data_file)
#
# ~\anaconda3\envs\pythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3384         )
#    3385
# -> 3386         return DataFrameRenderer(formatter).to_csv(
#    3387             path_or_buf,
#    3388             line_terminator=line_terminator,
#
# ...

# %% [markdown]
# Connect Pandas and SQL

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
# from config import db_password


db_string = f"postgres://postgres:{db_password}@localhost/cryptocurrency_db"

# %%
engine = create_engine(db_string)

# %%
df1.to_sql(name='crypto_data', con=engine)

# %%
currencies_df.to_sql(name='crypto_id', con=engine)

# %%
# check dataset
log_check = pd.read_sql_query('select COUNT(*) FROM "crypto_data"',con=engine)
log_check
